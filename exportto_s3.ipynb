# %% [markdown]
# # Export to S3 Function
#
# This notebook contains a function to export all files and folders from a SageMaker source directory to an S3 bucket folder.

# %%
import boto3
import os
from pathlib import Path
import logging
from botocore.exceptions import ClientError, NoCredentialsError

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
def export_directory_to_s3(bucket_name, s3_folder, source_directory, aws_access_key_id=None, aws_secret_access_key=None, region_name='us-east-1'):
    """
    Export all files and folders from a local directory to an S3 bucket folder.
    Overwrites existing files and adds new files.
    
    Args:
        bucket_name (str): Name of the S3 bucket
        s3_folder (str): Destination folder in S3 bucket
        source_directory (str): Local source directory path
        aws_access_key_id (str, optional): AWS access key ID. If None, uses default credentials
        aws_secret_access_key (str, optional): AWS secret access key. If None, uses default credentials
        region_name (str): AWS region name (default: 'us-east-1')
    
    Returns:
        bool: True if successful, False otherwise
    """
    try:
        # Create S3 client
        if aws_access_key_id and aws_secret_access_key:
            s3_client = boto3.client(
                's3',
                aws_access_key_id=aws_access_key_id,
                aws_secret_access_key=aws_secret_access_key,
                region_name=region_name
            )
        else:
            # Use default credentials (from ~/.aws/credentials, IAM role, etc.)
            s3_client = boto3.client('s3', region_name=region_name)
        
        # Ensure source directory exists
        source_path = Path(source_directory)
        if not source_path.exists():
            logger.error(f"Source directory '{source_directory}' does not exist")
            return False
        
        # Ensure s3_folder doesn't start with '/' and ends with '/'
        if s3_folder.startswith('/'):
            s3_folder = s3_folder[1:]
        if not s3_folder.endswith('/'):
            s3_folder += '/'
        
        logger.info(f"Starting upload from '{source_directory}' to 's3://{bucket_name}/{s3_folder}'")
        
        uploaded_count = 0
        
        # Walk through all files and directories in the source directory
        for root, dirs, files in os.walk(source_directory):
            # Process all files in current directory
            for file in files:
                # Get full local file path
                local_file_path = os.path.join(root, file)
                
                # Calculate relative path from source directory
                relative_path = os.path.relpath(local_file_path, source_directory)
                
                # Create S3 key (object path)
                s3_key = s3_folder + relative_path.replace('\\', '/')  # Use forward slashes for S3
                
                try:
                    # Upload file to S3
                    s3_client.upload_file(local_file_path, bucket_name, s3_key)
                    uploaded_count += 1
                    logger.info(f"Uploaded: {relative_path} -> s3://{bucket_name}/{s3_key}")
                    
                except ClientError as e:
                    logger.error(f"Error uploading {relative_path}: {e}")
                    continue
                except FileNotFoundError:
                    logger.error(f"File not found: {local_file_path}")
                    continue
        
        if uploaded_count == 0:
            logger.warning(f"No files found in directory '{source_directory}'")
        else:
            logger.info(f"Successfully uploaded {uploaded_count} files to s3://{bucket_name}/{s3_folder}")
        
        return True
        
    except NoCredentialsError:
        logger.error("AWS credentials not found. Please configure your credentials.")
        return False
    except ClientError as e:
        error_code = e.response['Error']['Code']
        if error_code == 'NoSuchBucket':
            logger.error(f"Bucket '{bucket_name}' does not exist")
        elif error_code == 'AccessDenied':
            logger.error(f"Access denied to bucket '{bucket_name}'. Check your permissions.")
        else:
            logger.error(f"AWS error: {e}")
        return False
    except Exception as e:
        logger.error(f"Unexpected error: {e}")
        return False

# %% [markdown]
# ## Usage Examples
#
# Here's how to use the function with your specific parameters:

# %%
# Example 1: Using your specific parameters (with default AWS credentials)
bucket_name = "sagemaker-studio-940544301691-64iyil0o5a"
s3_folder = "nlp_assignment"
source_directory = "/home/sagemaker-user/codespace/nlp_assignments"

success = export_directory_to_s3(bucket_name, s3_folder, source_directory)
if success:
    print(f"Successfully exported files from {source_directory} to s3://{bucket_name}/{s3_folder}/")
else:
    print("Export failed")
# Out:
# INFO:__main__:Starting upload from '/home/sagemaker-user/codespace/nlp_assignments' to 's3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/'
# INFO:__main__:Uploaded: import_from_s3.ipynb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/import_from_s3.ipynb
# INFO:__main__:Uploaded: import_from_s3.ipynb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/import_from_s3.ipynb
# INFO:__main__:Uploaded: hw3.ipynb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/hw3.ipynb
# INFO:__main__:Uploaded: hw3.ipynb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/hw3.ipynb
# INFO:__main__:Uploaded: second-test-data-DIST.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/second-test-data-DIST.json
# INFO:__main__:Uploaded: second-test-data-DIST.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/second-test-data-DIST.json
# INFO:__main__:Uploaded: test-results.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/test-results.txt
# INFO:__main__:Uploaded: test-results.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/test-results.txt
# INFO:__main__:Uploaded: exportto_s3.ipynb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/exportto_s3.ipynb
# INFO:__main__:Uploaded: exportto_s3.ipynb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/exportto_s3.ipynb
# INFO:__main__:Uploaded: .vscode/settings.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/.vscode/settings.json
# INFO:__main__:Uploaded: .vscode/settings.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/.vscode/settings.json
# INFO:__main__:Uploaded: wandb/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/debug.log
# INFO:__main__:Uploaded: wandb/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/debug.log
# INFO:__main__:Uploaded: wandb/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/debug-internal.log
# INFO:__main__:Uploaded: wandb/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/run-4rudza1h.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/run-4rudza1h.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/run-4rudza1h.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/run-4rudza1h.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_193330-4rudza1h/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193330-4rudza1h/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/run-v55o1f26.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/run-v55o1f26.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/run-v55o1f26.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/run-v55o1f26.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_193643-v55o1f26/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_193643-v55o1f26/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/run-hng6226n.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/run-hng6226n.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/run-hng6226n.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/run-hng6226n.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_194545-hng6226n/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_194545-hng6226n/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/run-tps47lg2.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/run-tps47lg2.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/run-tps47lg2.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/run-tps47lg2.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_195621-tps47lg2/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195621-tps47lg2/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/run-082i5l04.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/run-082i5l04.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/run-082i5l04.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/run-082i5l04.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_195807-082i5l04/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_195807-082i5l04/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/run-zsjb9gyp.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/run-zsjb9gyp.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/run-zsjb9gyp.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/run-zsjb9gyp.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_200048-zsjb9gyp/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200048-zsjb9gyp/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/run-9bc24a0q.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/run-9bc24a0q.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/run-9bc24a0q.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/run-9bc24a0q.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_200458-9bc24a0q/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_200458-9bc24a0q/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/run-firgnpsz.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/run-firgnpsz.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/run-firgnpsz.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/run-firgnpsz.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_201212-firgnpsz/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201212-firgnpsz/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/run-df9bqs35.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/run-df9bqs35.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/run-df9bqs35.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/run-df9bqs35.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_201807-df9bqs35/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_201807-df9bqs35/files/config.yaml
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/run-tfy7t5fp.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/run-tfy7t5fp.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/run-tfy7t5fp.wandb -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/run-tfy7t5fp.wandb
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/logs/debug.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/logs/debug.log
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/logs/debug-internal.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/logs/debug-internal.log
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/logs/debug-core.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/logs/debug-core.log
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/files/wandb-metadata.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/files/wandb-metadata.json
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/files/requirements.txt -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/files/requirements.txt
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/files/output.log -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/files/output.log
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/files/wandb-summary.json -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/files/wandb-summary.json
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/files/config.yaml
# INFO:__main__:Successfully uploaded 93 files to s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/
# INFO:__main__:Uploaded: wandb/run-20251113_202219-tfy7t5fp/files/config.yaml -> s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/wandb/run-20251113_202219-tfy7t5fp/files/config.yaml
# INFO:__main__:Successfully uploaded 93 files to s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/
# Successfully exported files from /home/sagemaker-user/codespace/nlp_assignments to s3://sagemaker-studio-940544301691-64iyil0o5a/nlp_assignment/

# %%
# # Example 2: Using explicit credentials (if needed)
# bucket_name = "sagemaker-studio-940544301691-64iyil0o5a"
# s3_folder = "nlp_assignment"
# source_directory = "/home/sagemaker-user/codespace/nlp_assignments"
# access_key = "YOUR_ACCESS_KEY_ID"  # Replace with your access key
# secret_key = "YOUR_SECRET_ACCESS_KEY"  # Replace with your secret key

# success = export_directory_to_s3(
#     bucket_name=bucket_name,
#     s3_folder=s3_folder,
#     source_directory=source_directory,
#     aws_access_key_id=access_key,
#     aws_secret_access_key=secret_key,
#     region_name='us-east-1'  # Adjust region if needed
# )

# if success:
#     print(f"Successfully exported files from {source_directory} to s3://{bucket_name}/{s3_folder}/")
# else:
#     print("Export failed")

# %%
# # Example 3: Quick function for your specific use case
# def export_nlp_assignments():
#     """Quick function to export your NLP assignments to S3"""
#     return export_directory_to_s3(
#         bucket_name="sagemaker-studio-940544301691-64iyil0o5a",
#         s3_folder="nlp_assignment",
#         source_directory="/home/sagemaker-user/codespace/nlp_assignments"
#     )

# # Simply call this function to export your files
# # success = export_nlp_assignments()
# # print("Export completed!" if success else "Export failed!")

# %% [markdown]
# ## Function Features
#
# - **Complete directory upload**: Uploads all files and subfolders recursively
# - **Overwrites existing files**: Files with the same name will be replaced
# - **Preserves folder structure**: Maintains the original directory structure in S3
# - **Handles large files**: Uses efficient file upload methods
# - **Error handling**: Comprehensive error handling and logging
# - **Flexible authentication**: Supports both default AWS credentials and explicit credentials
#
# ## Prerequisites
#
# 1. **AWS credentials configured** in one of these ways:
#    - IAM role (recommended for SageMaker)
#    - AWS credentials file (`~/.aws/credentials`)
#    - Environment variables (`AWS_ACCESS_KEY_ID`, `AWS_SECRET_ACCESS_KEY`)
#    - Or pass credentials directly to the function
#
# 2. **Required Python packages** (usually pre-installed in SageMaker):
#    ```bash
#    pip install boto3
#    ```
#
# 3. **S3 permissions**: Write access to the specified bucket
